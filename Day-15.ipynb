# %% [markdown]
# # [--- Day 15: ??? ---](https://adventofcode.com/2023/day/15)

# %%
from PIL import Image
image = Image.open("craiyon_fuzzy_unicorn_cat.jpg.png")
image.show("Day 15 Mascot")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=256x256>

# %% [markdown]
# ## Setup
#
# Use the `input` file if present, otherwise use the sample input.

# %%
import numpy as np
is_sample = False

try:
  input = open("input", "r").read().splitlines()
except FileNotFoundError:
  input = """#.##..##.
..#.##.#.
##......#
##......#
..#.##.#.
..##..##.
#.#.##.#.

#...##..#
#....#..#
..##..###
#####.##.
#####.##.
..##..###
#....#..#"""

  input = input.split("\n")
  is_sample = True

print(input)
# Out:
# ['#.##..##.', '..#.##.#.', '##......#', '##......#', '..#.##.#.', '..##..##.', '#.#.##.#.', '', '#...##..#', '#....#..#', '..##..###', '#####.##.', '#####.##.', '..##..###', '#....#..#']

# %% [markdown]
# ## Functions and Classes

# %%
def get_horiz(grid):
# Out:
#   Cell In[5], line 1
#     def get_horiz(grid):
#                         ^
# SyntaxError: incomplete input

# %% [markdown]
# ## Part 1

# %%
res = 0

for grid in grids:
    res += score(grid)

print(res)
#assert(res == 405 or res == 36015)

# %% [markdown]
# ## Part 2

# %%
res = 0


print(res)
#assert(res == 400 or res == 35335)
